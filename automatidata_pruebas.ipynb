# %% [markdown]
# # Automatidata
# ##Capstone Google Advanced Data Analyticso
# ### Encabezado más peque

# %%
import pandas as pd
import numpy as np

# Asegúrate de escribir 'read_csv' correctamente
df = pd.read_csv("C:/Users/victo/OneDrive/Data_Science/Python/taxi_trip_data_actualizado.csv")

# Imprime el DataFrame
print(df)
print
df.head()
# Out:
#               ID  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0       24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1       35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2      106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3       38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4       30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
# ...          ...       ...                     ...                     ...
# 22694   14873857         2   02/24/2017 5:37:23 PM   02/24/2017 5:40:39 PM
# 22695   66632549         2   08/06/2017 4:43:59 PM   08/06/2017 5:24:47 PM
# 22696   74239933         2   09/04/2017 2:54:14 PM   09/04/2017 2:58:22 PM
# 22697   60217333         2  07/15/2017 12:56:30 PM   07/15/2017 1:08:26 PM
# 22698   17208911         1   03/02/2017 1:02:49 PM   03/02/2017 1:16:09 PM
#
# ...

# %%
# !pip install seaborn
# Out:
# ...
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    ---------------------------------------- 0.0/294.9 kB ? eta -:--:--
#    - -------------------------------------- 10.2/294.9 kB ? eta -:--:--
#    ---- ---------------------------------- 30.7/294.9 kB 660.6 kB/s eta 0:00:01
#    ---------- ---------------------------- 81.9/294.9 kB 762.6 kB/s eta 0:00:01
#    ---------------------- ----------------- 163.8/294.9 kB 1.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 174.1/294.9 kB 1.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 174.1/294.9 kB 1.1 MB/s eta 0:00:01
#    ----------------------- ---------------- 174.1/294.9 kB 1.1 MB/s eta 0:00:01
#    ----------------------------------- -- 276.5/294.9 kB 896.4 kB/s eta 0:00:01
#    ----------------------------------- -- 276.5/294.9 kB 896.4 kB/s eta 0:00:01
#    ------------------------------------ - 286.7/294.9 kB 655.2 kB/s eta 0:00:01
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Verificar si hay valores nulos
if df.isnull().values.any():
    # Visualización de valores nulos
    sns.heatmap(df.isnull(), cbar=False, cmap="viridis")
    plt.title("Mapa de valores nulos")
    plt.show()
else:
    print("No se encontraron valores nulos en el conjunto de datos.")
# Out:
# No se encontraron valores nulos en el conjunto de datos.

# %%
import pandas as pd
import numpy as np

# Asegúrate de escribir 'read_csv' correctamente
df = pd.read_csv("C:/Users/victo/OneDrive/Data_Science/Python/taxi_trip_data_actualizado.csv")

# Imprime el DataFrame
print(df)
print
df.head(10)
# Out:
#               ID  VendorID    tpep_pickup_datetime   tpep_dropoff_datetime  \
# 0       24870114         2   03/25/2017 8:55:43 AM   03/25/2017 9:09:47 AM
# 1       35634249         1   04/11/2017 2:53:28 PM   04/11/2017 3:19:58 PM
# 2      106203690         1   12/15/2017 7:26:56 AM   12/15/2017 7:34:08 AM
# 3       38942136         2   05/07/2017 1:17:59 PM   05/07/2017 1:48:14 PM
# 4       30841670         2  04/15/2017 11:32:20 PM  04/15/2017 11:49:03 PM
# ...          ...       ...                     ...                     ...
# 22694   14873857         2   02/24/2017 5:37:23 PM   02/24/2017 5:40:39 PM
# 22695   66632549         2   08/06/2017 4:43:59 PM   08/06/2017 5:24:47 PM
# 22696   74239933         2   09/04/2017 2:54:14 PM   09/04/2017 2:58:22 PM
# 22697   60217333         2  07/15/2017 12:56:30 PM   07/15/2017 1:08:26 PM
# 22698   17208911         1   03/02/2017 1:02:49 PM   03/02/2017 1:16:09 PM
#
# ...

# %%
import pandas as pd

# Asegurarnos de que las columnas estén en formato datetime
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# Calcular duración del viaje en minutos
df['trip_duration'] = (df['tpep_dropoff_datetime'] - df['tpep_pickup_datetime']).dt.total_seconds() / 3600

# Obtener las 10 duraciones más largas
longest_trips = df.nlargest(10, 'trip_duration')[['trip_duration', 'tpep_pickup_datetime', 'tpep_dropoff_datetime']]

# Imprimir resultados con índice
print("Las 10 duraciones más largas son:")
print(longest_trips)
# Out:
# Las 10 duraciones más largas son:
#        trip_duration tpep_pickup_datetime tpep_dropoff_datetime
# 924        23.992500  2017-02-09 23:24:58   2017-02-10 23:24:31
# 15579      23.985833  2017-05-10 18:53:53   2017-05-11 18:53:02
# 14998      23.980833  2017-07-31 14:04:25   2017-08-01 14:03:16
# 22638      23.977500  2017-04-03 21:02:49   2017-04-04 21:01:28
# 15163      23.975833  2017-04-13 23:41:09   2017-04-14 23:39:42
# 7939       23.974444  2017-06-30 20:36:00   2017-07-01 20:34:28
# 21366      23.971111  2017-12-14 17:21:37   2017-12-15 17:19:53
# 6751       23.967222  2017-06-14 11:51:18   2017-06-15 11:49:20
# 6493       23.963889  2017-06-27 16:52:07   2017-06-28 16:49:57
# 18650      23.949444  2017-10-05 10:51:03   2017-10-06 10:48:01

# %%
import seaborn as sns  # Asegúrate de importar seaborn
import matplotlib.pyplot as plt  # Para graficar

# Crear un histograma de la columna 'trip_distance'
sns.histplot(df['trip_distance'], bins=30, kde=True)
plt.title("Distribución de la distancia del viaje")
plt.xlabel("Distancia (millas)")
plt.show()

# %%
# identicar viajes largos anomalos
# Umbral para definir viajes largos
long_trips = df[df['trip_distance'] > 20]
print(f"Viajes largos encontrados: {len(long_trips)}")
# Out:
# Viajes largos encontrados: 136

# %%
# ingresos totales por tipo de pago
total_income = df.groupby('payment_type')['total_amount'].sum()
print(total_income)
total_income.plot(kind='bar', title='Ingresos totales por tipo de pago')
plt.ylabel('Total ($)')
plt.show()
# Out:
# payment_type
# 1    269634.51
# 2     98437.48
# 3      1643.14
# 4       516.96
# Name: total_amount, dtype: float64

# %%
print(df.columns)
# Out:
# Index(['ID', 'VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'trip_duration'],
#       dtype='object')

# %%
# mapear codigos a descripcciones legibles
rate_code_map = {
    1: "Tarifa estándar",
    2: "JFK",
    3: "Newark",
    4: "Nassau o Westchester",
    5: "Tarifa negociada",
    6: "Viaje en grupo"
}

df['RatecodeID'] = df['RatecodeID'].map(rate_code_map)
print(df[['RatecodeID']].head())
# Out:
#         RatecodeID
# 0  Tarifa estándar
# 1  Tarifa estándar
# 2  Tarifa estándar
# 3  Tarifa estándar
# 4  Tarifa estándar

# %%
# exportar datos procesados 
output_path = "C:/Users/victo/OneDrive/Data_Science/Python/taxi_trip_data_procesado.csv"
df.to_csv(output_path, index=False)
print("Archivo exportado exitosamente.")
# Out:
# Archivo exportado exitosamente.

# %%
# filtrar datos por tipo de pago (payment_type=1)
# Filtrar viajes con pago por tarjeta de crédito
credit_card_payments = df[df['payment_type'] == 1]
print(credit_card_payments.head())
# Out:
#           ID  VendorID tpep_pickup_datetime tpep_dropoff_datetime  \
# 0   24870114         2  2017-03-25 08:55:43   2017-03-25 09:09:47
# 1   35634249         1  2017-04-11 14:53:28   2017-04-11 15:19:58
# 2  106203690         1  2017-12-15 07:26:56   2017-12-15 07:34:08
# 3   38942136         2  2017-05-07 13:17:59   2017-05-07 13:48:14
# 5   23345809         2  2017-03-25 20:34:11   2017-03-25 20:42:11
#
#    passenger_count  trip_distance       RatecodeID store_and_fwd_flag  \
# 0                6           3.34  Tarifa estándar                  N
# 1                1           1.80  Tarifa estándar                  N
# 2                1           1.00  Tarifa estándar                  N
# 3                1           3.70  Tarifa estándar                  N
# 5                6           2.30  Tarifa estándar                  N
#
#    PULocationID  DOLocationID  payment_type  fare_amount  extra  mta_tax  \
# ...
